# %%
# !pip install onnxruntime opencv-python numpy

# %%
pip install torch torchvision
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import onnxruntime as ort

ort_session = ort.InferenceSession('bestm.onnx')

# %%
print("Input details:", ort_session.get_inputs())
print("Output details:", ort_session.get_outputs())
# Out:
# Input details: [<onnxruntime.capi.onnxruntime_pybind11_state.NodeArg object at 0x00000246CCAB3CB0>]
# Output details: [<onnxruntime.capi.onnxruntime_pybind11_state.NodeArg object at 0x00000246CD1E5D30>]

# %%
pip install ipykernel --force-reinstall
# Out:
# ...
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached debugpy-1.8.5-cp311-cp311-win_amd64.whl.metadata (1.1 kB)
# ...
#   Using cached ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached jupyter_client-8.6.2-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached psutil-6.0.0-cp37-abi3-win_amd64.whl.metadata (22 kB)
# ...
#   Using cached pyzmq-26.2.0-cp311-cp311-win_amd64.whl.metadata (6.2 kB)
# ...
#   Using cached tornado-6.4.1-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# ...
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# ...

# %%
# !python -m pip install backports.tarfile

# %%
# model testing through live integrated laptop camera
# !python yolov5/detect.py --weights bestm.onnx --img 640 --conf 0.25 --source 0 --device cpu
# Out:
# detect: weights=['bestm.onnx'], source=0, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Nidhi': No such file or directory
# YOLOv5  2024-8-31 Python-3.11.3 torch-2.4.0+cpu CPU
#
# Loading bestm.onnx for ONNX Runtime inference...
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 640x640 (no detections), 191.5ms
# 0: 640x640 (no detections), 160.4ms
# 0: 640x640 (no detections), 140.2ms
# 0: 640x640 (no detections), 140.1ms
# 0: 640x640 (no detections), 144.0ms
# 0: 640x640 (no detections), 146.9ms
# 0: 640x640 (no detections), 144.7ms
# ...

# %%
# model testing on a downloaded video
# !python yolov5/detect.py --weights bestm.onnx --img 640 --conf 0.25 --source "\public_awareness.mp4" --device cpu
# Out:
# detect: weights=['bestm.onnx'], source=\public_awareness.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Nidhi': No such file or directory
# YOLOv5  2024-8-31 Python-3.11.3 torch-2.4.0+cpu CPU
#
# Loading bestm.onnx for ONNX Runtime inference...
# Traceback (most recent call last):
#   File "c:\Users\Nidhi Satyapriya\OneDrive\Desktop\SIH_2024\yolov5\detect.py", line 437, in <module>
#     main(opt)
#   File "c:\Users\Nidhi Satyapriya\OneDrive\Desktop\SIH_2024\yolov5\detect.py", line 432, in main
#     run(**vars(opt))
# ...

# %%
# model testing on test dataset
# !python yolov5/detect.py --weights bestm.onnx --img 640 --conf 0.25 --source trash-detection.v35-avec-toutes-les-data-augmentation-dt-contrast-29.yolov5pytorch\test\images --device cpu
# Out:
# detect: weights=['bestm.onnx'], source=trash-detection.v35-avec-toutes-les-data-augmentation-dt-contrast-29.yolov5pytorch\test\images, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Nidhi': No such file or directory
# YOLOv5  2024-8-31 Python-3.11.3 torch-2.4.0+cpu CPU
#
# Loading bestm.onnx for ONNX Runtime inference...
# ...

# %%
# model testing on validation datasets
# !python yolov5/detect.py --weights bestm.onnx --img 640 --conf 0.25 --source trash-detection.v35-avec-toutes-les-data-augmentation-dt-contrast-29.yolov5pytorch\valid\images --source 1 --device cpu

# %%
# model testing on custom dataset- taken from IIITBH campus

# !python yolov5/detect.py --weights bestm.onnx --img 640 --conf 0.25 --source "C:\Users\Nidhi Satyapriya\OneDrive\Desktop\SIH_2024\kbh_kuda" --device cpu
# Out:
# detect: weights=['bestm.onnx'], source=C:\Users\Nidhi Satyapriya\OneDrive\Desktop\SIH_2024\kbh_kuda, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Nidhi': No such file or directory
# YOLOv5  2024-8-31 Python-3.11.3 torch-2.4.0+cpu CPU
#
# Loading bestm.onnx for ONNX Runtime inference...
# image 1/11 C:\Users\Nidhi Satyapriya\OneDrive\Desktop\SIH_2024\kbh_kuda\WhatsApp Image 2024-09-07 at 9.38.04 AM.jpeg: 640x640 1 Clear plastic bottle, 2 Plastic films, 1 Unlabeled litter, 234.4ms
# ...
